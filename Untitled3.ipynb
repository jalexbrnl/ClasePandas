# %% [markdown]
# <a href="https://colab.research.google.com/github/jalexbrnl/ClasePandas/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos = pd.read_csv('Datos.csv')
datos
# cantidad = datos.groupby(['Sexo']).sum()
# print(cantidad)
# datos.loc[datos['Sexo'] == 'm'] = 'M'
# (resultado)
nueva = datos.drop(columns= ['Sexo'])
nueva
# Out:
#          fecha reporte web  ID de caso Fecha de notificación  \
# 0      2020-12-24 00:00:00     1556982   2020-12-22 00:00:00
# 1      2020-12-24 00:00:00     1556986   2020-12-18 00:00:00
# 2      2020-11-08 00:00:00     1137434   2020-11-05 00:00:00
# 3      2020-11-08 00:00:00     1137440   2020-11-03 00:00:00
# 4      2020-11-08 00:00:00     1137443   2020-11-04 00:00:00
# ...                    ...         ...                   ...
# 77162  2020-12-23 00:00:00     1534088   2020-12-19 00:00:00
# 77163  2020-12-23 00:00:00     1534092   2020-12-19 00:00:00
# 77164  2020-09-11 00:00:00      699401   2020-09-08 00:00:00
# 77165  2020-09-11 00:00:00      699406   2020-09-08 00:00:00
# 77166  2020-09-11 00:00:00      699407   2020-09-07 00:00:00
#
#        Código DIVIPOLA departamento Nombre departamento  \
# 0                                76               VALLE
# 1                                76               VALLE
# 2                                11              BOGOTA
# ...

# %%
print(datos['sexo'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sexo'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-5150df72e4df> in <cell line: 1>()
# ----> 1 print(datos['sexo'])
#
# ...
